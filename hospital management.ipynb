# %%
from tkinter import *
import pymysql as p
from tkinter import ttk
from tkinter import messagebox
con = p.connect("localhost","root","akif123@","login")
cur=con.cursor()
class Staff:
    def remove(self):
        name1=str(self.doctor_name1.get())
        q22="delete from sttaf where doctor=%s"
        cur.execute(q22,name1)
        con.commit()
        messagebox.showinfo(self.window6,'DOCTOR REMOVE SUCCESFULLY')
    def staff_romove_doctor(self):
        self.doctor_name1=Entry(self.window6,width='34')
        self.add1=Button(self.window6,text='REMOVE DOCTOR',command=self.remove,height=1,width=18)
        self.doctor_name1.place(x=100,y=50)
        self.add1.place(x=130,y=100)
        
    def add(self):
        name=str(self.doctor_name.get())
        quer="insert into sttaf (doctor) values(%s)"
        cur.execute(quer,name)
        con.commit()
        messagebox.showinfo(self.window6,'DOCTOR ADDED SUCCESSFULLY')
    def staff_add_doctor(self):
        self.doctor_name=Entry(self.window6,width='34')
        self.add=Button(self.window6,text='  ADD DOCTOR  ',command=self.add,height=1,width=18)
        self.doctor_name.place(x=100,y=50)
        self.add.place(x=130,y=100)
        #query='insert into sttaf values'
    def staff_doctor_list(self):
        query="select doctor from sttaf "
        cur.execute(query)
        con.commit()
        self.data_doctor=cur.fetchall()
        b=200
        for self.row in self.data_doctor:
            self.label_doctor=Label(self.window6,text=self.row,bg='skyblue',fg='darkblue',font='Helvetica 14 bold')
            self.label_doctor.place(x=20,y=b)
            b=b+40
        
    def staff(self):
        self.window6=Tk()
        self.window6.configure(background='skyblue')
        self.window6.title('PATIENT DETAIL')
        self.window6.geometry('700x408+0+280')
        
        self.doctor_list=Button(self.window6,text='DOCTOR LIST',height=2,width=15,fg='blue',font='Helvetica 10 underline bold',command=self.staff_doctor_list)
        self.add_doctor=Button(self.window6,text='ADD DOCTOR',height=2,width=15,fg='blue',font='Helvetica 10 underline bold',command=self.staff_add_doctor)
        self.delete_doctor=Button(self.window6,text='REMOVE DOCTOR',height=2,width=15,fg='blue',font='Helvetica 10 underline bold',command=self.staff_romove_doctor)
        #self.nurse_list=Button(self.window6,text='NURSE LIST',height=2,width=15,fg='blue',font='Helvetica 10 underline bold')
        #self.add_nurse=Button(self.window6,text=' ADD NURSE',height=2,width=15,fg='blue',font='Helvetica 10 underline bold')
        #self.delete_nurse=Button(self.window6,text='REMOVE NURSE',height=2,width=15,fg='blue',font='Helvetica 10 underline bold')
        
        self.doctor_list.place(x=500,y=50)
        self.add_doctor.place(x=500,y=160)
        self.delete_doctor.place(x=500,y=270)
        #self.nurse_list.place(x=500,y=380)
        #self.add_nurse.place(x=500,y=490)
        #self.delete_nurse.place(x=500,y=600)
        
        self.window6.mainloop()
        
class Patient(Staff):
    gv=0
    def search(self):
        name7=self.box.get()
        q6="select *from patient_regis where name=%s"
        cur.execute(q6,name7)
        
        self.patient_detailed=cur.fetchall()
        con.commit()
        print(self.patient_detailed)
        self.registration_no7=Label(self.window5,text=self.patient_detailed[0][0],bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.name7=Label(self.window5,text=self.patient_detailed[0][1],bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.registration_date7=Label(self.window5,text=self.patient_detailed[0][2],bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.address7=Label(self.window5,text=self.patient_detailed[0][3],bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        #self.city7=Label(self.window5,text="CITY",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.mobile7=Label(self.window5,text=self.patient_detailed[0][4],bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        #self.gender65=Label(self.window5,text="GENDER",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.age7=Label(self.window5,text=self.patient_detailed[0][5],bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.marital_status7=Label(self.window5,text=self.patient_detailed[0][6],bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        
        self.registration_no7.place(x=0,y=150)
        self.name7.place(x=150,y=150)
        self.registration_date7.place(x=300,y=150)
        self.address7.place(x=430,y=150)
        self.mobile7.place(x=600,y=150)
        self.age7.place(x=750,y=150)
        self.marital_status7.place(x=900,y=150)
        
        
    def patient_detail(self):
        self.window5=Tk()
        self.window5.configure(background='skyblue')
        self.window5.title('PATIENT DETAIL')
        self.window5.geometry('1100x350+100+400')
        self.box=Entry(self.window5,width='35')
        self.search=Button(self.window5,text='SEARCH',height=2,width=13,fg='blue',font='Helvetica 10 underline bold',command=self.search)
        self.registration_no6=Label(self.window5,text="REGISTRATION\nNUMBER",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.name6=Label(self.window5,text="NAME",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.registration_date6=Label(self.window5,text="REGISTRATION\nDATE ",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.address6=Label(self.window5,text="ADDRESS",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        #self.city6=Label(self.window5,text="CITY",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.mobile6=Label(self.window5,text="MOBILE",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        #self.gender65=Label(self.window5,text="GENDER",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.age6=Label(self.window5,text="AGE",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        self.marital_status6=Label(self.window5,text="MARITAL STATUS",bg='skyblue',fg='darkblue',font='Helvetica 10 bold')
        
        self.registration_no6.place(x=0,y=100)
        self.name6.place(x=150,y=100)
        self.registration_date6.place(x=300,y=100)
        self.address6.place(x=430,y=100)
        self.mobile6.place(x=600,y=100)
        self.age6.place(x=750,y=100)
        self.marital_status6.place(x=900,y=100)
        
        self.box.place(x=280,y=20)
        self.search.place(x=530,y=20)
        self.window5.mainloop()
        
    def patient_database(self):
        registration_no4=str(self.e41.get())
        name4=str(self.e42.get())
        registration_date4=str(self.e43.get())
        add4=str(self.e45.get('1.0',END))
        #city4=self.city_name.get()
        #print(city4)
        mobile4=str(self.e46.get())
        #print(self.gender1.get())
        #if(self.gender1.get()==1):
         #   gender4='male'
        #elif(self.gender2.get()==1):
          #  gender4='female'
        age4=str(self.e47.get())
        marital4=str(self.e44.get())
        patient_info=(registration_no4,name4,registration_date4,add4,mobile4,age4,marital4)
        q4='insert into patient_regis (registration_no,name,registration_date,address,mobile,age,marital_status) values(%s,%s,%s,%s,%s,%s,%s)'
        cur.execute(q4,patient_info)
        con.commit()
        messagebox.showinfo(self.window4,'PATIENT DATA ADDED SUCCESSFULLY')
        print(patient_info)
        self.window4.destroy()
        
        
    def patient_entry(self):
        self.window4=Tk()
        self.window4.configure(background='skyblue')
        self.window4.title('PATIENT REGISTRATION')
        self.window4.geometry('1365x768')
        
        self.registration_no=Label(self.window4,text="REGISTRATION NUMBER ",bg='skyblue',fg='darkblue',font='Helvetica 18 bold')
        self.name=Label(self.window4,text="NAME",bg='skyblue',fg='darkblue',font='Helvetica 18 bold')
        self.registration_date=Label(self.window4,text="REGISTRATION DATE ",bg='skyblue',fg='darkblue',font='Helvetica 18 bold')
        self.address=Label(self.window4,text="ADDRESS",bg='skyblue',fg='darkblue',font='Helvetica 18 bold')
        self.city=Label(self.window4,text="CITY",bg='skyblue',fg='darkblue',font='Helvetica 18 bold')
        self.mobile=Label(self.window4,text="MOBILE",bg='skyblue',fg='darkblue',font='Helvetica 18 bold')
        self.gender=Label(self.window4,text="GENDER",bg='skyblue',fg='darkblue',font='Helvetica 18 bold')
        self.age=Label(self.window4,text="AGE",bg='skyblue',fg='darkblue',font='Helvetica 18 bold')
        self.marital_status=Label(self.window4,text="MARITAL STATUS",bg='skyblue',fg='darkblue',font='Helvetica 18 bold')
        #self.city_name=StringVar()
        #self.gender1=IntVar()
        #self.gender2=IntVar()
        #self.comb=ttk.Combobox(self.window4,textvariable=self.city_name)
        #self.comb['values']=('ALLAHABAD','LUCKNOW','AGRA','KANPUR','FATHEPUR')
        #self.gen=Radiobutton(self.window4,text='male',padx=25,bg='skyblue',variable=self.gender1,value=1,command=v)
        #self.gen2=Radiobutton(self.window4,text='female',padx=25,bg='skyblue',variable=self.gender2,value=2,command=v)
        #self.comb.set('Select')
        
        
        
        self.e41=Entry(self.window4,width='35')
        self.e42=Entry(self.window4,width='35')
        self.e43=Entry(self.window4,text='dd/mm/yy',width='35')
        self.e44=Entry(self.window4,width='35')
        self.e46=Entry(self.window4)
        self.e45=Text(self.window4,height=4,width=35)
        self.e47=Entry(self.window4,width='35')
        
        self.registration_no.place(x=30,y=50)
        self.name.place(x=30,y=100)
        self.registration_date.place(x=30,y=150)
        self.address.place(x=30,y=200)
        #self.city.place(x=30,y=300)
        self.mobile.place(x=30,y=350)
        #self.gender.place(x=30,y=400)
        self.age.place(x=30,y=450)
        self.marital_status.place(x=30,y=505)

        self.e41.place(x=400,y=50)
        self.e42.place(x=400,y=105)
        self.e43.place(x=400,y=160)
        self.e45.place(x=400,y=215)
        #self.comb.place(x=400,y=295)
        self.e46.place(x=400,y=350)
        #self.gen.place(x=400,y=400)
        #self.gen2.place(x=490,y=400)
        self.e47.place(x=400,y=455)
        self.e44.place(x=400,y=510)
        self.submit=Button(self.window4,text="SUBMIT",fg='darkblue',height=2,width=15,font='Helvetica 13 underline bold',command=self.patient_database)
        self.submit.place(x=370,y=570)
        self.window4.mainloop()
        
class Create(Patient):
    
    
    def hospital(self):
        self.window2=Tk()
        self.window2.configure(background='skyblue')
        self.window2.title('WELCOME')
        self.window2.geometry('1365x768')
        self.label3=Label(self.window2,text=" WELCOME TO HOSPITAL MANAGEMENT SYSTEM",bg='skyblue',fg='darkblue',font='Helvetica 37 underline bold')
        self.b11=Button(self.window2,text='PATIENT ENTRY',height=2,width=25,fg='blue',font='Helvetica 13 underline bold',command=self.patient_entry)
        self.b21=Button(self.window2,text='PATIENTS DETAIL',height=2,width=25,fg='blue',font='Helvetica 13 underline bold',command=self.patient_detail)
        self.b31=Button(self.window2,text='STAFF INFORMATION',height=2,width=25,fg='blue',font='Helvetica 13 underline bold',command=self.staff)
        self.b41=Button(self.window2,text='BLOOD BANK',height=2,width=25,fg='blue',font='Helvetica 13 underline bold')
        self.b51=Button(self.window2,text='BILLING',height=2,width=25,fg='blue',font='Helvetica 13 underline bold')
        self.b61=Button(self.window2,text='PATHOLOGY',height=2,width=25,fg='blue',font='Helvetica 13 underline bold')
        
        self.b11.place(x=1000,y=100)
        self.b21.place(x=1000,y=200)
        self.b31.place(x=1000,y=300)
        self.b41.place(x=1000,y=400)
        self.b51.place(x=1000,y=500)
        self.b61.place(x=1000,y=600)
        
        self.label3.place(x=80,y=10)
        self.window2.mainloop()
    
class Login(Create):
    def __init__(self):
        print('mohd akif usmani')
        
    def created(self):
        name2=str(self.e3.get())
        email2=str(self.e4.get())
        pd2=str(self.e5.get())
        mob2=int(self.e6.get())
        user_info=(name2,pd2,email2,mob2)
        q2="insert into regis (name,password,email,mobile) values(%s,%s,%s,%s)"
        cur.execute(q2,user_info)
        messagebox.showinfo(self.window3,'DATA ADDED SUCCESSFULLY')
        print('data submiited')
        con.commit()
        self.window3.destroy()
        
        
        
    def create_new_account(self):
        self.window3=Tk()
        self.window3.configure(background='skyblue')
        self.window3.title('CREATE NEW ACCOUNT')
        self.window3.geometry("500x400+500+200")
        
        self.name=Label(self.window3,text='NAME',bg='skyblue', font='Helvetica 18 bold')
        self.email=Label(self.window3,text='E-MAIL',bg='skyblue',font='Helvetica 18 bold')
        self.PASSWORD=Label(self.window3,text='PASSWORD',bg='skyblue', font='Helvetica 18 bold')
        self.MOB=Label(self.window3,text='MOBILE NUMBER',bg='skyblue', font='Helvetica 18 bold')
        self.b3=Button(self.window3,text='SUBMIT',height=1,width=10,fg='blue', font='Helvetica 14 underline bold',command=self.created)
    
        self.e3=Entry(self.window3)
        self.e4=Entry(self.window3)
        self.e5=Entry(self.window3)
        self.e6=Entry(self.window3)
        
        self.name.place(x=50,y=50)
        self.email.place(x=50,y=100)
        self.PASSWORD.place(x=50,y=150)
        self.MOB.place(x=50,y=200)
        
        self.e3.place(x=280,y=55)
        self.e4.place(x=280,y=105)
        self.e5.place(x=280,y=155)
        self.e6.place(x=280,y=205)
        self.b3.place(x=240,y=270)
        
        self.window3.mainloop()
        
        
    def login(self):
        self.email=str(self.e1.get())
        print(self.email)
        self.pd=str(self.e2.get())
        print(self.pd)
        user_info=(self.email,self.pd)
        q="select email,password from regis"
        cur.execute(q)
        data=cur.fetchall()
        con.commit()
        if(user_info in data):
            self.window.destroy()
            self.hospital()
            
                
        else:
            self.label=Label(self.window,text='worng detail!!',bg='yellow',fg='red',font='Helvetica 13 bold')
            self.label.place(x=130,y=250)
        return None
    
    
    def login1(self):
        self.window=Tk()
        self.window.title('LOGIN')
        self.window.configure(background='yellow')
        self.label=Label(self.window,text='   WELCOME TO HOSPITAL\n   MANAGEMENT SYSTEM',fg='blue', font='Helvetica 25 bold',bg='yellow')
        self.ID=Label(self.window,text='EMAIL' , font='Helvetica 18 bold',bg='yellow')
        self.PASSWORD=Label(self.window,text='PASSWORD', font='Helvetica 18 bold',bg='yellow')
        self.e1=Entry(self.window)
        self.e2=Entry(self.window)
        self.b1=Button(self.window,text='LOGIN',height=2,width=8,fg='blue',font='Helvetica 13 underline bold',command=self.login)
        self.b2=Button(self.window,text='CREATE NEW ACCOUNT',height=2,width=20,fg='blue',font='Helvetica 13 underline bold',command=self.create_new_account)
        self.ID.place(x=100,y=150)
        self.PASSWORD.place(x=100,y=200)
        self.e1.place(x=280,y=150)
        self.e2.place(x=280,y=200)
        self.b1.place(x=150,y=300)
        self.b2.place(x=260,y=300)
        self.label.place(x=20,y=20)
        self.window.geometry("500x400+500+200")
        self.window.mainloop()  
l=Login()
l.login1()
# Out:
# mohd akif usmani
